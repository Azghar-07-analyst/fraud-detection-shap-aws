# %%
import pandas as pd
import sys
sys.path.append('D:/Projects/fraud-detection-shap-aws')
from utils.config_loader import load_config
from sqlalchemy import create_engine

config = load_config('D:/Projects/fraud-detection-shap-aws/configs/creditcard_config.json')
print("Config loaded")
# Out:
# Config loaded: Credit Card Fraud
# ✓ Config loaded

# %%
df = pd.read_csv('D:/Projects/fraud-detection-shap-aws/data/processed/creditcard_processed.csv')
print(f"Loaded {len(df):,} rows from processed file")
print(f"Columns: {list(df.columns)}")
# Out:
# Loaded 284,807 rows from processed file
# Columns: ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class', 'Amount_Scaled', 'Time_Scaled']

# %%
engine = create_engine('mysql+pymysql://root:Azghar__07@localhost/fraud_detection')

df[['Time_Scaled', 'Amount_Scaled', 'Class']].to_sql(
    'transactions',
    con=engine,
    if_exists='replace',
    index=False
)

print(f"{len(df):,} rows loaded into MySQL")
print("Open MySQL Workbench and run the 6 SQL queries now")
# Out:
# 284,807 rows loaded into MySQL
# Open MySQL Workbench and run the 6 SQL queries now
